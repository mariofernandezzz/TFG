# %%
# Librería o conjunto de herramientas para el uso de lenguaje natural
import nltk 

# Modelo para tokenización
nltk.download('punkt')  
nltk.download('punkt_tab') 
# Corpus que contiene stopwords en diferentes idiomas
nltk.download('stopwords') 
nltk.download('wordnet')
nltk.download('pos_tag')


#Herramienta para tokenizar separando por palabras
from nltk.tokenize import word_tokenize 
#Importar el la herramienta con el corpus de stopwords
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk import pos_tag

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Librería que contiene herramientas de lematización
import spacy
# Cargar el modelo de spaCy para inglés
nlp = spacy.load("en_core_web_sm")


# Librería para carga de datos
import pandas as pd

# Herrmienta para contar la frecuencia
from collections import defaultdict
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mario.fernandezr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\mario.fernandezr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mario.fernandezr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mario.fernandezr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading pos_tag: Package 'pos_tag' not found in
# [nltk_data]     index

# %%
ruta_digcomp = "../data/digcomp/digcomp_nivelCompetencia.csv"
digcomp = pd.read_csv(ruta_digcomp, encoding="latin1")

digcomp = digcomp[digcomp['Idioma'] != 'Español']

# %%
def tokenizar_texto_wordnet(texto):
    tokens = word_tokenize(texto)
    return [token for token in tokens]

# %%
def tokenizar_texto_spacy(texto):
    doc = nlp(texto.lower())
    return list(doc)

# %%
def eliminar_stopwords_wordnet(tokens):
    return [token for token in tokens if token.isalpha() and token not in stop_words]

# %%
def eliminar_stopwords_spacy(tokens):
    return [token for token in tokens if token.is_alpha and not token.is_stop]

# %%
def lematizar_texto_wordnet(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

# %%
def lematizar_texto_spacy(tokens):
    return [token.lemma_.lower() for token in tokens]

# %%
tokens_spacy = digcomp["Texto"].apply(tokenizar_texto_spacy)
tokens_filtrados = tokens_spacy.apply(eliminar_stopwords_spacy)
digcomp["Palabras spacy"] = tokens_filtrados.apply(lematizar_texto_spacy)

tokens_wordnet = digcomp["Texto"].apply(tokenizar_texto_wordnet)
tokens_filtrados = tokens_wordnet.apply(eliminar_stopwords_wordnet)
digcomp["Palabras wordnet"] = tokens_filtrados.apply(lematizar_texto_wordnet)

display(digcomp)
# Out:
#      ID_area  ID_competencia  Idioma  ID_nivel  ID_nivelCompetencia  \
# 27         1               1  Inglés         1                    1
# 28         1               1  Inglés         1                    2
# 29         1               1  Inglés         1                    3
# 30         1               1  Inglés         2                    1
# 31         1               1  Inglés         2                    2
# ..       ...             ...     ...       ...                  ...
# 724        5               4  Inglés         6                    3
# 725        5               4  Inglés         7                    1
# 726        5               4  Inglés         7                    2
# 727        5               4  Inglés         8                    1
# 728        5               4  Inglés         8                    2
#
#                                                  Texto             Verbo  \
# 27   identify my information needs, find data, info...          identify
# 28   find how to access these data, information and...              find
# 29         identify simple personal search strategies.          identify
# 30                      identify my information needs.          identify
# 31   find data, information and content through a s...              find
# ..                                                 ...               ...
# 724  choose the most appropriate opportunities for ...            choose
# 725  create solutions to complex problems with limi...            create
# 726  integrate my knowledge to contribute to profes...  integrate, guide
# 727  create solutions to solve complex problems wit...            create
# 728      propose new ideas and processes to the field.           propose
#
#                                         Palabras spacy  \
# 27   [identify, information, need, find, datum, inf...
# 28   [find, access, datum, information, content, na...
# 29      [identify, simple, personal, search, strategy]
# 30                       [identify, information, need]
# 31   [find, datum, information, content, simple, se...
# ..                                                 ...
# 724  [choose, appropriate, opportunity, self, devel...
# 725  [create, solution, complex, problem, limited, ...
# 726  [integrate, knowledge, contribute, professiona...
# 727  [create, solution, solve, complex, problem, in...
# 728               [propose, new, idea, process, field]
#
#                                       Palabras wordnet
# 27   [identify, information, need, find, data, info...
# 28   [find, access, data, information, content, nav...
# 29      [identify, simple, personal, search, strategy]
# 30                       [identify, information, need]
# 31   [find, data, information, content, simple, sea...
# ..                                                 ...
# 724  [choose, appropriate, opportunity, keep, date,...
# 725  [create, solution, complex, problem, limited, ...
# 726  [integrate, knowledge, contribute, professiona...
# 727  [create, solution, solve, complex, problem, ma...
# 728               [propose, new, idea, process, field]
#
# [365 rows x 9 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
# Explota la columna "Palabras x" para que cada token ocupe una fila.
spacy = digcomp.explode("Palabras spacy")
wordn = digcomp.explode("Palabras wordnet")
 

# Agrupa por ID_area, ID_competencia y palabra, y cuenta la cantidad de ocurrencias de cada palabra
tabla_frecuencias_spacy = (
    spacy
    .groupby(["Palabras spacy"])
    .size()
    .reset_index(name="Frecuencia")
)

tabla_frecuencias_wn = (
    wordn
    .groupby(["Palabras wordnet"])
    .size()
    .reset_index(name="Frecuencia")
)

# Mostrar la tabla resultante
display(tabla_frecuencias_spacy)
# Out:
#       Palabras spacy  Frecuencia
# 0             access           6
# 1                act           3
# 2              adapt          18
# 3             adjust           6
# 4            analyse           2
# 5           analysis           5
# 6              apply          29
# 7           appraise           1
# 8         appropiate           1
# 9        appropriate          50
# 10   appropriateness           1
# 11            aspect           6
# 12            assess          10
# 13       attribution           6
# 14          audience           8
# 15             avoid           8
# 16       behavioural           6
# 17            browse           3
# 18             carry           3
# 19            change           2
# 20            choose          18
# 21           citizen           6
# 22       citizenship           3
# 23           clarify           1
# 24                co           6
# 25         cognitive           5
# 26     collaborative           8
# 27      collectively           6
# 28            common           2
# 29     communication          14
# 30        comparison           2
# 31        competence          12
# 32           complex          41
# 33           compute          10
# 34        conceptual           6
# 35          consider           5
# 36         construct           2
# 37      construction           1
# 38           content          80
# 39           context           6
# 40        contribute          20
# 41         copyright           9
# 42            create          62
# 43          creation           9
# 44        creatively           1
# 45       credibility           6
# 46          credible           2
# 47        critically           2
# 48          cultural           8
# 49         customise           8
# 50            damage           5
# 51            danger          11
# 52              date           8
# 53             datum          76
# 54            decide           2
# 55            define          44
# 56        definition          20
# 57       demonstrate           1
# 58          describe           5
# 59            detect           2
# 60         determine           1
# 61           develop           4
# 62       development          12
# 63            device          17
# 64         different          34
# 65     differentiate          13
# 66           digital         256
# 67      discriminate           4
# 68           discuss          12
# 69           display           1
# 70         diversity           8
# 71            easily           1
# 72              easy           2
# 73              edit           5
# 74           edition           2
# 75       elaborating           1
# 76            employ           1
# 77           empower           6
# 78            engage           5
# 79        enviroment           1
# 80       environment          91
# 81     environmental           3
# 82         etiquette           3
# 83          evaluate           4
# 84        evaluation           7
# 85         evolution           6
# 86             exist           2
# 87           explain          17
# 88           express           6
# 89        expression           3
# 90            factor          21
# 91             field          21
# 92            filter           2
# 93         filtering           1
# 94              find           9
# 95            follow           2
# 96            format           8
# 97               gap           1
# 98      generational           8
# 99              give           8
# 100            guide          20
# 101           health           9
# 102             idea          21
# 103     identifiable           7
# 104         identify          40
# 105         identity           9
# 106       illustrate           4
# 107           impact           8
# 108          improve          16
# 109        inclusion           8
# 110         indicate          15
# 111     individually           6
# 112      information          75
# 113         innovate           4
# 114       innovative           2
# 115      instruction           8
# 116        integrate          29
# 117         interact          33
# 118      interaction           3
# 119         interest           1
# 120     intermediary           3
# 121   intermediation           1
# 122   interpretation           2
# 123             item           5
# 124             know           6
# 125         knowlede           1
# 126        knowledge          50
# 127          licence           1
# 128          license           8
# 129          limited          20
# 130             list           4
# 131           manage           8
# 132       management           1
# 133       manipulate           3
# 134             mean          16
# 135          measure           8
# 136             mode           2
# 137           modify           5
# 138        modifying           3
# 139         multiple           1
# 140         navigate           6
# 141             need          33
# 142              new          39
# 143             norm           6
# 144           obtain           1
# 145              one           8
# 146           online           7
# 147          operate           3
# 148        operating           7
# 149      opportunity           8
# 150            order           8
# 151     organisation           4
# 152         organise          12
# 153         original           8
# 154      participate          12
# 155          perform          14
# 156         personal          31
# 157       personally           7
# 158         physical           6
# 159             plan           2
# 160           policy           8
# 161         possible          10
# 162         practice          26
# 163          privacy          25
# 164          problem          68
# 165          process          36
# 166       processing           6
# 167          produce           6
# 168          product           6
# 169     professional          20
# 170      programming           1
# 171          propose          25
# 172          protect          46
# 173       protection           3
# 174    psychological           6
# 175            range           1
# 176        recognise          14
# 177      referencing           6
# 178           refine           5
# 179         refining           3
# 180           regard           6
# 181           relate          38
# 182      reliability          14
# 183         reliable           2
# 184       reputation           8
# 185          resolve           7
# 186         resource           3
# 187       respectful           2
# 188          respond           1
# 189         response           9
# 190        retrieval           4
# 191         retrieve           4
# 192             risk          13
# 193             role           1
# 194          routine          41
# 195        routinely           1
# 196             rule           6
# 197           safety           8
# 198           search          14
# 199        searching           1
# 200         security           8
# 201             seek           4
# 202           select          28
# 203             self          15
# 204          service          17
# 205            share          20
# 206           simple          84
# 207        situation           6
# 208           social          15
# 209          society          12
# 210         solution          48
# 211            solve          36
# 212           source           9
# 213         specific           6
# 214        statement           6
# 215          storage           4
# 216            store           4
# 217         strategy          13
# 218       structured           9
# 219          support           2
# 220           system          10
# 221             task           8
# 222        technical           9
# 223    technological           9
# 224       technology          78
# 225           threat          16
# 226             tool          33
# 227       understand           4
# 228           update           6
# 229              use          28
# 230          variety           9
# 231             vary           7
# 232              way          68

# %%
display(tabla_frecuencias_wn)
# Out:
#     Palabras wordnet  Frecuencia
# 0                  I           8
# 1             access           6
# 2                act           3
# 3              adapt          13
# 4            adapted           5
# 5             adjust           6
# 6              among           1
# 7          analysing           2
# 8           analysis           5
# 9              apply          24
# 10          applying           5
# 11          appraise           1
# 12        appropiate           1
# 13       appropriate          50
# 14   appropriateness           1
# 15            aspect           6
# 16            assess          10
# 17       attribution           6
# 18          audience           8
# 19             avoid           6
# 20          avoiding           2
# 21       behavioural           6
# 22          browsing           3
# 23             carry           3
# 24            change           2
# 25            choose          18
# 26           citizen           6
# 27       citizenship           3
# 28           clarify           1
# 29         cognitive           5
# 30     collaborative           8
# 31      collectively           6
# 32            common           2
# 33     communication          14
# 34        comparison           2
# 35        competence          12
# 36           complex          41
# 37         computing          10
# 38        conceptual           6
# 39          consider           5
# 40           content          80
# 41           context           6
# 42        contribute          20
# 43         copyright           9
# 44            create          60
# 45          creation           8
# 46        creatively           1
# 47       credibility           6
# 48          credible           2
# 49        critically           2
# 50          cultural           8
# 51         customise           8
# 52            damage           5
# 53            danger          11
# 54              data          76
# 55              date           1
# 56            decide           2
# 57        definition          20
# 58       demonstrate           1
# 59          describe           5
# 60            detect           2
# 61         determine           1
# 62           develop           1
# 63        developing           3
# 64       development           4
# 65            device          17
# 66         different          34
# 67     differentiate          13
# 68           digital         256
# 69      discriminate           4
# 70            discus          12
# 71           display           1
# 72         diversity           8
# 73               due           6
# 74            easier           1
# 75            easily           1
# 76              easy           1
# 77              edit           5
# 78           edition           2
# 79            employ           1
# 80           empower           6
# 81            engage           2
# 82          engaging           3
# 83       enviroments           1
# 84       environment          91
# 85     environmental           3
# 86         etiquette           3
# 87          evaluate           2
# 88        evaluating           2
# 89        evaluation           7
# 90         evolution           6
# 91          existing           2
# 92           explain          17
# 93           express           6
# 94        expression           1
# 95            factor          21
# 96             field          21
# 97         filtering           3
# 98              find           8
# 99            follow           2
# 100           format           8
# 101            found           1
# 102              gap           1
# 103     generational           8
# 104            given           8
# 105            guide          20
# 106           health           9
# 107             idea          21
# 108     identifiable           7
# 109         identify          38
# 110      identifying           2
# 111         identity           9
# 112       illustrate           4
# 113           impact           8
# 114          improve           6
# 115         improved           5
# 116        improving           5
# 117        inclusion           8
# 118         indicate          15
# 119     individually           6
# 120      information          75
# 121         innovate           4
# 122       innovative           2
# 123      instruction           8
# 124        integrate          25
# 125      integrating           4
# 126         interact           4
# 127      interacting          29
# 128      interaction           3
# 129         interest           1
# 130     intermediary           3
# 131   intermediation           1
# 132   interpretation           2
# 133             item           5
# 134             keep           8
# 135         knowlede           1
# 136        knowledge          50
# 137          licence           1
# 138          license           8
# 139          limited          20
# 140             list           4
# 141       management           1
# 142         managing           8
# 143       manipulate           3
# 144             many          21
# 145             mean          16
# 146          measure           8
# 147             mode           2
# 148           modify           5
# 149        modifying           3
# 150         multiple           1
# 151         navigate           6
# 152             need          33
# 153              new          39
# 154             norm           6
# 155           obtain           1
# 156              one           8
# 157           online           7
# 158          operate           2
# 159        operating           8
# 160      opportunity           8
# 161            order           8
# 162     organisation           4
# 163         organise          11
# 164        organised           1
# 165         original           8
# 166           others          37
# 167      participate          12
# 168          perform          12
# 169       performing           2
# 170         personal          31
# 171       personally           7
# 172         physical           6
# 173         planning           2
# 174           policy           8
# 175         possible          10
# 176         practice          26
# 177          privacy          25
# 178          problem          68
# 179          process          35
# 180        processed           1
# 181       processing           6
# 182          produce           5
# 183         produced           1
# 184          product           6
# 185     professional          20
# 186      programming           1
# 187          propose          25
# 188          protect          28
# 189       protecting          18
# 190       protection           3
# 191    psychological           6
# 192            range           1
# 193        recognise          14
# 194      referencing           6
# 195           refine           5
# 196         refining           3
# 197           regard           6
# 198          related          38
# 199      reliability          14
# 200         reliable           2
# 201       reputation           8
# 202          resolve           7
# 203         resource           3
# 204       respectful           2
# 205          respond           1
# 206         response           9
# 207        retrieval           4
# 208         retrieve           3
# 209        retrieved           1
# 210             risk          13
# 211             role           1
# 212          routine          41
# 213        routinely           1
# 214             rule           6
# 215           safety           8
# 216           search          11
# 217        searching           4
# 218         security           8
# 219             seek           4
# 220           select          28
# 221             self           5
# 222          service          17
# 223          several           2
# 224            share          11
# 225          sharing           9
# 226             show           8
# 227           simple          84
# 228        situation           6
# 229           social          15
# 230          society          12
# 231         solution          48
# 232            solve          35
# 233          solving           1
# 234           source           9
# 235         specific           6
# 236        statement           6
# 237          storage           4
# 238            store           3
# 239           stored           1
# 240         strategy          13
# 241       structured           9
# 242          support           2
# 243           system          10
# 244             task           8
# 245        technical           9
# 246    technological           9
# 247       technology          78
# 248           threat          16
# 249             tool          33
# 250       understand           4
# 251           update           1
# 252          updated           5
# 253              use          28
# 254             used          10
# 255            using          33
# 256          variety           9
# 257             vary           7
# 258              way          68
