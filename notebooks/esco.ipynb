# %% [markdown]
# ## Importación de librerías
#
# En esta sección se importan las principales librerías utilizadas en el preprocesamiento del texto.
#
# - **spaCy**: biblioteca de procesamiento del lenguaje natural (NLP) que permite realizar tareas como tokenización, eliminación de stopwords o lematización.
#     - Se incluye además la configuración personalizada del tokenizador de spaCy, que permite ajustar cómo se separan los tokens (por ejemplo, evitar divisiones innecesarias en palabras con guiones, puntos, etc.).
# - **pandas**: biblioteca para la manipulación de datos estructurados (tablas) de tipo DataFrame.

# %%
# Librería que contiene herramientas de lematización
import spacy
from spacy.tokenizer import Tokenizer
from spacy.util import compile_infix_regex

# Librería para carga de datos
import pandas as pd

# %% [markdown]
# ## Definición de funciones y configuración de preprocesamiento
#
# Este bloque incluye todo lo necesario para preparar el texto antes de su análisis. Se utiliza el modelo `en_core_web_lg` de spaCy y se personaliza el tokenizador para evitar divisiones en guiones.
#
# ### Componentes definidos:
#
# - **Carga y personalización del modelo spaCy**: se modifica el tokenizador para no dividir palabras por guiones.
# - **`tokenizar_texto_spacy(texto)`**: convierte una cadena de texto a minúsculas y la transforma en una lista de tokens.
# - **`eliminar_stopwords_spacy(tokens)`**: elimina tokens irrelevantes, incluyendo stopwords, palabras no alfabéticas y una lista personalizada de palabras excluidas.
# - **`lematizar_texto_spacy(tokens)`**: transforma cada token en su lema o raíz.
# - **`aplicar_mapeo(serie_de_listas, mapeo)`**: aplica un diccionario de equivalencias léxicas para unificar términos similares.
# - **`palabras_extra`**: lista manual de palabras irrelevantes específicas del contexto del corpus.
# - **`mapeo`**: diccionario de normalización construido a partir de un archivo `.csv` externo.

# %%
# Cargar el modelo grande de inglés (incluye vectores de palabras)
nlp = spacy.load("en_core_web_lg")

# Eliminar los guiones como separadores internos para evitar fragmentación de tokens como "ai-based" en "ai" "based"
infixes = [x for x in nlp.Defaults.infixes if "-" not in x]
infix_re = compile_infix_regex(infixes)

# Reconfigurar el tokenizador con las nuevas reglas de infijos
nlp.tokenizer = Tokenizer(
    nlp.vocab,
    rules=nlp.Defaults.tokenizer_exceptions,
    prefix_search=nlp.tokenizer.prefix_search,
    suffix_search=nlp.tokenizer.suffix_search,
    infix_finditer=infix_re.finditer,
    token_match=nlp.tokenizer.token_match
)



# Función de tokenización básica con spaCy en la que también se pasa el texto en minúsculas
# La separación en tokens se realiza según las reglas del modelo de lenguaje cargado,
# teniendo en cuenta espacios, puntuación, signos de puntuación interna (como guiones, apóstrofes, etc.)
# y excepciones predefinidas. En este caso, se ha modificado el tokenizer para que no divida por guiones.
def tokenizar_texto_spacy(texto):
    doc = nlp(texto.lower())
    return list(doc)




# Lista personalizada de palabras a ignorar (además de las stopwords de spaCy)
palabras_extra = [
    "co", "digital", "alexa", "anytime", "cortana", "arduino", "bitcoin",
    "deepl", "digitally", "digitise", "dropbox", "duckduckgo", "e", "etc",
    "eurostat", "example", "facebook", "google", "miro", "t", "twitter",
    "tpm", "youtube", "vs", "whatsapp", "wikipedia", "x", "en", "se", "lego",
    "non", "python", "ros", "scratch", "siri", "-", "non-digital", "one-time",
    "bas", "digital-based", "digitise", "digitised", "digitization", "s", "whilst"
]

# Asegurar que "3d" y "3-d" no se consideren stopwords, ya que el eliminador de stopwrods 
# elimina todas con números
nlp.vocab["3d"].is_alpha = True
nlp.vocab["3-d"].is_alpha = True
nlp.vocab["2d"].is_alpha = True
nlp.vocab["2-d"].is_alpha = True

# Función para eliminar stopwords y tokens no alfabéticos.
# Ignora las palabras_extra
def eliminar_stopwords_spacy(tokens):
    return [
        token for token in tokens
        if not token.is_stop
        and token.is_alpha
        and token.text.lower() not in palabras_extra
    ]
    
    
    
    
# Función de lematización del modelos cargado
def lematizar_texto_spacy(tokens):
    return [token.lemma_ for token in tokens]




# Función de mapeo de palabras en función de un diccionario de mapeo para normalización de términos
def aplicar_mapeo(serie_de_listas, mapeo):
    return serie_de_listas.apply(lambda tokens: [mapeo.get(token, token) for token in tokens])



#carga del archivo que contiene los mapeos correspondientes y conversión a tipo DataFrame para ser tratado como tabla
ruta_mapeo = "../utils/mapping.csv"
df_mapeo = pd.read_csv(ruta_mapeo)

# Construcción del diccionario: original -> equivalente
mapeo = dict(zip(df_mapeo["original"], df_mapeo["equivalente"]))

# %% [markdown]
# ## Estructuración de datos
# - **Datos**: 1 fichero csv con la información de digital skills de ESCO.
#
# - **Texto analizado**:
#   - Descripción de la competencia.
#   - Preferred Label: nombre principal para identificar la copetencia.
#
# - **Agrupación**:
#   - Broader Concept: grupos a los que pertenecen las competencias.
#
# - **Proceso**:
#
#   1. Para cada competencia, uno el texto de:
#      - `description` de la competencia.
#      - `preferredLabel`.
#   2. Se unen los textos que comparten grupos en la columna `broaderConceptPT`

# %%
# Carga del archivo con información de la tabla de ESCO y conversión a tipo DataFrame
ruta_esco = "../data/esco/digitalSkillsCollection_en_4_PropiasDescripcionEliminadas.csv"
esco = pd.read_csv(ruta_esco, encoding="latin1")

esco.head()
# Out:
#                        preferredLabel  \
# 0      use global distribution system
# 1  use computer telephony integration
# 2                     use ICT systems
# 3      handle geospatial technologies
# 4            operate signal generator
#
#                                          description  \
# 0  Operate a computer reservations system or a gl...
# 1  Utilise technology that allows interaction bet...
# 2  Select and use ICT systems for a variety of co...
# 3  Can use Geospatial Technologies which involve ...
# 4  Use electronic devices or software tone genera...
#
#                        broaderConceptPT
# 0  accessing and analysing digital data
# 1  accessing and analysing digital data
# 2  accessing and analysing digital data
# 3  accessing and analysing digital data
# 4  accessing and analysing digital data

# %%
# Paso 1: Crear una columna con el texto combinado por competencia
esco["Texto"] = esco["preferredLabel"].astype(str) + ' ' + esco["description"].astype(str)

# Paso 2: Agrupar por broaderConceptPT y unir los textos combinados de las competencias
def unir_textos(textos):
    return ' '.join(textos)

esco_agrupado = esco.groupby("broaderConceptPT")["Texto"].agg(unir_textos).reset_index()

display(esco_agrupado)
# Out:
#                                      broaderConceptPT  \
# 0                                        CAD software
# 1                                              EU law
# 2                                  ICT infrastructure
# 3                ICT project management methodologies
# 4                                          ICT safety
# ..                                                ...
# 438                        wholesale and retail sales
# 439                                       work skills
# 440                            working with computers
# 441     working with digital devices and applications
# 442  working with machinery and specialised equipment
#
#                                                  Texto
# 0    CADD software The computer-aided design and dr...
# 1    GDPR The General Data Protection Regulation is...
# 2    proxy servers The proxy tools which act as an ...
# 3    Agile project management The agile project man...
# 4    protect the environment from the impact of the...
# ..                                                 ...
# 438  e-procurement The functioning and methods used...
# 439  data quality assessment The process of reveali...
# 440  manage changes in ICT system Plan, realise and...
# 441  operate digital hardware Use equipment such as...
# 442  monitor automated machines Continuously check ...
#
# [443 rows x 2 columns]

# %% [markdown]
# ## Obtención de lemas para la revisión de palabras
#
# El análisis de frecuencias es una técnica fundamental en el preprocesamiento de texto que permite observar qué términos aparecen con mayor recurrencia en un corpus. En este caso, se utiliza para revisar el resultado del procesamiento y facilitar la toma de decisiones sobre dos aspectos clave:
#
# - **Revisión de términos para mapeo léxico:** detectar palabras similares que podrían unificarse mediante reglas de mapeo.
# - **Identificación de palabras irrelevantes:** encontrar términos frecuentes pero poco informativos, susceptibles de ser añadidos a una lista personalizada de stopwords.
#
# ### Proceso general
#
#    - Preprocesamiento completo del texto (incluido stopwords con palabras adcicionales y mapeos consegudiso hasta el momento)
#    - Agrupación de todos los tokens del corpus en el que se obtienen las frecuencias de cada palabra (con función `obtener_frecuencias`).
#    - Exportación a archivo externo en el que se pueden analizar manualmente las palabras.
#
# ### Utilidad práctica
#
# Este análisis permite:
# - Detectar errores o inconsistencias en el preprocesamiento.
# - Afinar los criterios de mapeo léxico para mejorar la representación semántica.
# - Ampliar la lista de stopwords personalizadas con términos que resulten frecuentes pero irrelevantes en el dominio analizado.

# %%
# Paso 1: Unir y concatenar los textos de todas las tablas
texto_concatenado = pd.concat([
    esco_agrupado["Texto"]
], ignore_index=True)

# Paso 2: Aplicar el preprocesamiento completo a cada texto
texto_tokenizado = texto_concatenado.apply(tokenizar_texto_spacy)
texto_filtrado = texto_tokenizado.apply(eliminar_stopwords_spacy)
texto_lematizado = texto_filtrado.apply(lematizar_texto_spacy)
texto_mapeado = aplicar_mapeo(texto_lematizado, mapeo)

# Paso 3: Crear un DataFrame con los textos mapeados para explotar los tokens
tokens = pd.DataFrame({"Texto": texto_mapeado})

# Paso 4: Definición de función para obtener frecuencias
def obtener_frecuencias(df):
    # Explota la lista de palabras de la columna "Texto"
    df_explotado = df.explode("Texto")

    # Renombra la columna para mayor claridad
    df_explotado = df_explotado.rename(columns={"Texto": "Palabra"})

    # Agrupa por palabra y cuenta ocurrencias
    tabla_frecuencias = (
        df_explotado
        .groupby("Palabra")
        .size()
        .reset_index(name="Frecuencia")
        .sort_values(by="Frecuencia", ascending=False)
    )

    return tabla_frecuencias

# Paso 5: Calcular frecuencias
frecuencias = obtener_frecuencias(tokens)

# Paso 6: Exportar a CSV para revisión manual
frecuencias.to_csv("../utils/tokens_revisar_esco.csv", index=False)

# %% [markdown]
# ## Aplicación del preprocesamiento a los textos de las dimensiones
#
# En este bloque se aplica el flujo de preprocesamiento definido anteriormente (tokenización, eliminación de stopwords, lematización y mapeo) a las distintas tablas de texto correspondientes a varias dimensiones del marco de competencias.
#
# se transforma la columna `"Texto"` de la tabla siguiendo el mismo flujo, con el objetivo de normalizar los textos y prepararlos para análisis posteriores (como comparación semántica).

# %%
esco_tokens = esco_agrupado["Texto"].apply(tokenizar_texto_spacy)
esco_sinStopwords = esco_tokens.apply(eliminar_stopwords_spacy)
esco_lematizado = esco_sinStopwords.apply(lematizar_texto_spacy)
esco_agrupado["Texto"] = aplicar_mapeo(esco_lematizado, mapeo)

display(esco_agrupado)
# Out:
#                                      broaderConceptPT  \
# 0                                        CAD software
# 1                                              EU law
# 2                                  ICT infrastructure
# 3                ICT project management methodologies
# 4                                          ICT safety
# ..                                                ...
# 438                        wholesale and retail sales
# 439                                       work skills
# 440                            working with computers
# 441     working with digital devices and applications
# 442  working with machinery and specialised equipment
#
#                                                  Texto
# 0    [cadd, software, design, draft, cadd, use, com...
# 1    [gdpr, general, datum, protect, regulate, euro...
# 2    [proxy, server, proxy, tool, act, intermediati...
# 3    [agile, project, manage, agile, project, manag...
# 4    [protect, environment, impact, technology, awa...
# ..                                                 ...
# 438  [function, method, manage, electronic, purchas...
# 439  [datum, quality, assess, process, reveal, datu...
# 440  [manage, change, ict, system, plan, realise, m...
# 441  [operate, hardware, use, equipment, monitor, m...
# 442  [monitor, automation, machine, continue, check...
#
# [443 rows x 2 columns]

# %% [markdown]
# ## Funciones para análisis de frecuencias por grupo
#
# Este bloque permite calcular, filtrar y revisar frecuencias de palabras dentro de grupos definidos (por área, competencia, etc.).
#
# ### Componentes definidos:
#
# - **`obtener_frecuencias_por_grupo(df, columnas_grupo)`**: genera una tabla de frecuencias por palabra dentro de cada grupo definido.
# - **`filtrar_por_umbral_por_grupo(tabla, columnas_grupo)`**: filtra palabras frecuentes aplicando un umbral (media + desviación) dentro de cada grupo.
# - **`imprimir_estadisticas_por_grupo(nombre, tabla_original, tabla_filtrada, columnas_grupo)`**: imprime estadísticas básicas del filtrado para cada grupo.

# %%
# Función para generar la tabla de frecuencias por grupo
def obtener_frecuencias_por_grupo(df, columnas_grupo):
    # Explota la columna "Texto", que contiene listas de palabras, en filas individuales
    df_explotado = df.explode("Texto")

    # Renombra la columna para que se entienda que cada fila representa una palabra
    df_explotado = df_explotado.rename(columns={"Texto": "Palabra"})

    # Agrupa por las columnas indicadas (grupo) y por palabra, y cuenta ocurrencias
    tabla_frecuencias = (
        df_explotado
        .groupby(columnas_grupo + ["Palabra"])
        .size()
        .reset_index(name="Frecuencia")
    )

    return tabla_frecuencias
    
    
# Función para filtrar palabras por grupo según un umbral
def filtrar_por_umbral_por_grupo(tabla_frecuencias, columnas_grupo):
    
    # Función interna que calcula el umbral y filtra un solo grupo
    def filtrar_grupo(grupo):
        media = grupo["Frecuencia"].mean()
        desviacion = grupo["Frecuencia"].std()
        umbral = media + desviacion
        return grupo[grupo["Frecuencia"] > umbral]
    
    # Aplica el filtrado a cada grupo y devuelve el resultado combinado
    return tabla_frecuencias.groupby(columnas_grupo, group_keys=False).apply(filtrar_grupo).reset_index(drop=True)


# Función para imprimir estadísticas descriptivas por grupo
def imprimir_estadisticas_por_grupo(nombre_tabla, tabla_frecuencias, tabla_frecuencias_filtradas, columnas_grupo):

    print(f"=== {nombre_tabla} ===")
    
    # Recorre cada grupo para calcular sus estadísticas y mostrar comparativas
    for nombre_grupo, grupo in tabla_frecuencias.groupby(columnas_grupo):
        total_original = grupo.shape[0]
        media = grupo["Frecuencia"].mean()
        desviacion = grupo["Frecuencia"].std()
        umbral = media + desviacion
        
        # Crea una máscara lógica para identificar el grupo correspondiente en la tabla filtrada
        if isinstance(nombre_grupo, tuple):
            mascara = True
            for col, val in zip(columnas_grupo, nombre_grupo):
                mascara &= (tabla_frecuencias_filtradas[col] == val)
        else:
            mascara = (tabla_frecuencias_filtradas[columnas_grupo] == nombre_grupo)
            
        grupo_filtrado = tabla_frecuencias_filtradas[mascara]
        total_filtrado = grupo_filtrado.shape[0]

        # Imprime resultados por grupo
        nombre = ", ".join(str(val) for val in nombre_grupo) if isinstance(nombre_grupo, tuple) else str(nombre_grupo)
        print(f"--- Grupo: {nombre} ---")
        print(f"Total de palabras (antes del filtrado): {total_original}")
        print(f"Total de palabras (después del filtrado): {total_filtrado}")
        print(f"Media de frecuencia: {media:.2f}")
        print(f"Desviación típica: {desviacion:.2f}")
        print(f"Umbral aplicado (media + desviación): {umbral:.2f}")
        print()

# %% [markdown]
# ## Cálculo de frecuencias por dimensión y grupo
#
# Este bloque ejecuta el análisis de frecuencias por grupos definidos en distintas dimensiones del marco competencial. Para cada grupo:
#
# 1. Se calcula la frecuencia total de palabras (`esco_sinUmbral`).
# 2. Se filtran las más relevantes usando un umbral estadístico (`esco_filtrado`).
# 3. Se imprimen estadísticas básicas para revisión.

# %%
esco_sinUmbral = obtener_frecuencias_por_grupo(esco_agrupado, ["broaderConceptPT"])
esco_filtrado = filtrar_por_umbral_por_grupo(esco_sinUmbral, ["broaderConceptPT"])
imprimir_estadisticas_por_grupo("Broader Concept", esco_sinUmbral, esco_filtrado, ["broaderConceptPT"])
# Out:
# C:\Users\mario.fernandezr\AppData\Local\Temp\ipykernel_17916\3679962933.py:31: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return tabla_frecuencias.groupby(columnas_grupo, group_keys=False).apply(filtrar_grupo).reset_index(drop=True)
# === Broader Concept ===
# --- Grupo: CAD software ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.50
# Desviación típica: 0.83
# Umbral aplicado (media + desviación): 2.33
#
# --- Grupo: EU law ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.31
# Desviación típica: 0.63
# Umbral aplicado (media + desviación): 1.94
#
# --- Grupo: ICT infrastructure ---
# Total de palabras (antes del filtrado): 39
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.59
# Desviación típica: 1.12
# Umbral aplicado (media + desviación): 2.71
#
# --- Grupo: ICT project management methodologies ---
# Total de palabras (antes del filtrado): 31
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 4.68
# Desviación típica: 3.51
# Umbral aplicado (media + desviación): 8.18
#
# --- Grupo: ICT safety ---
# Total de palabras (antes del filtrado): 52
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.81
# Desviación típica: 1.51
# Umbral aplicado (media + desviación): 3.32
#
# --- Grupo: ICT software specifications ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.31
# Desviación típica: 0.85
# Umbral aplicado (media + desviación): 2.16
#
# --- Grupo: accessing and analysing digital data ---
# Total de palabras (antes del filtrado): 106
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.68
# Desviación típica: 1.48
# Umbral aplicado (media + desviación): 3.16
#
# --- Grupo: accounting and taxation ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.15
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.64
#
# --- Grupo: adapt to change ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.40
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.92
#
# --- Grupo: address an audience ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.25
# Desviación típica: 0.45
# Umbral aplicado (media + desviación): 1.70
#
# --- Grupo: adhere to organisational guidelines ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.13
# Desviación típica: 0.35
# Umbral aplicado (media + desviación): 1.49
#
# --- Grupo: adopt ways to reduce negative impact of consumption ---
# Total de palabras (antes del filtrado): 5
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.80
# Desviación típica: 0.84
# Umbral aplicado (media + desviación): 2.64
#
# --- Grupo: advise customers on new equipment ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.22
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.66
#
# --- Grupo: advise customers on type of computer equipment ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.40
# Desviación típica: 0.63
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: advise on customs regulations ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.22
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.66
#
# --- Grupo: advise others ---
# Total de palabras (antes del filtrado): 25
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.24
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.76
#
# --- Grupo: advising on products and services ---
# Total de palabras (antes del filtrado): 37
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.41
# Desviación típica: 0.93
# Umbral aplicado (media + desviación): 2.33
#
# --- Grupo: advocating for individual or community needs ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.06
# Desviación típica: 0.24
# Umbral aplicado (media + desviación): 1.30
#
# --- Grupo: allocating and controlling physical resources ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.27
# Desviación típica: 0.47
# Umbral aplicado (media + desviación): 1.74
#
# --- Grupo: allocating and controlling resources ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.25
# Desviación típica: 0.58
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: analyse ICT system ---
# Total de palabras (antes del filtrado): 39
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.23
# Desviación típica: 0.48
# Umbral aplicado (media + desviación): 1.72
#
# --- Grupo: analyse big data ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.40
# Desviación típica: 0.91
# Umbral aplicado (media + desviación): 2.31
#
# --- Grupo: analyse images ---
# Total de palabras (antes del filtrado): 7
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.43
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 1.96
#
# --- Grupo: analyse scientific data ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.38
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.89
#
# --- Grupo: analyse ship operations ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.21
# Desviación típica: 0.43
# Umbral aplicado (media + desviación): 1.64
#
# --- Grupo: analyse test data ---
# Total de palabras (antes del filtrado): 27
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.30
# Desviación típica: 0.87
# Umbral aplicado (media + desviación): 2.17
#
# --- Grupo: analysing and evaluating information and data ---
# Total de palabras (antes del filtrado): 84
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.58
# Desviación típica: 1.68
# Umbral aplicado (media + desviación): 3.26
#
# --- Grupo: analysing business operations ---
# Total de palabras (antes del filtrado): 110
# Total de palabras (después del filtrado): 9
# Media de frecuencia: 1.85
# Desviación típica: 1.98
# Umbral aplicado (media + desviación): 3.83
#
# --- Grupo: analysing scientific and medical data ---
# Total de palabras (antes del filtrado): 27
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.33
# Desviación típica: 0.68
# Umbral aplicado (media + desviación): 2.01
#
# --- Grupo: apply 3D imaging techniques ---
# Total de palabras (antes del filtrado): 21
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.52
# Desviación típica: 1.12
# Umbral aplicado (media + desviación): 2.65
#
# --- Grupo: apply basic programming skills ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.30
# Desviación típica: 0.48
# Umbral aplicado (media + desviación): 1.78
#
# --- Grupo: apply company policies ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.32
# Desviación típica: 0.89
# Umbral aplicado (media + desviación): 2.21
#
# --- Grupo: apply digital security measures ---
# Total de palabras (antes del filtrado): 23
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.13
# Desviación típica: 0.34
# Umbral aplicado (media + desviación): 1.47
#
# --- Grupo: apply social media marketing ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.14
# Desviación típica: 0.64
# Umbral aplicado (media + desviación): 1.78
#
# --- Grupo: apply statistical analysis techniques ---
# Total de palabras (antes del filtrado): 31
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.48
# Desviación típica: 0.96
# Umbral aplicado (media + desviación): 2.45
#
# --- Grupo: apply teaching strategies ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.20
# Desviación típica: 0.42
# Umbral aplicado (media + desviación): 1.62
#
# --- Grupo: assemble machines ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.33
# Desviación típica: 0.82
# Umbral aplicado (media + desviación): 2.15
#
# --- Grupo: assembling electrical and electronic products ---
# Total de palabras (antes del filtrado): 39
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.38
# Desviación típica: 0.81
# Umbral aplicado (media + desviación): 2.20
#
# --- Grupo: assess financial viability ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.36
# Desviación típica: 0.50
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: assess operating cost ---
# Total de palabras (antes del filtrado): 23
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.43
# Desviación típica: 0.73
# Umbral aplicado (media + desviación): 2.16
#
# --- Grupo: assess quality of services ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.10
# Desviación típica: 0.31
# Umbral aplicado (media + desviación): 1.41
#
# --- Grupo: audio-visual techniques and media production ---
# Total de palabras (antes del filtrado): 223
# Total de palabras (después del filtrado): 28
# Media de frecuencia: 1.99
# Desviación típica: 1.87
# Umbral aplicado (media + desviación): 3.86
#
# --- Grupo: browsing, searching and filtering digital data ---
# Total de palabras (antes del filtrado): 52
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.50
# Desviación típica: 1.15
# Umbral aplicado (media + desviación): 2.65
#
# --- Grupo: building and civil engineering ---
# Total de palabras (antes del filtrado): 42
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.24
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 1.77
#
# --- Grupo: care of the elderly and of disabled adults ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.09
# Desviación típica: 0.30
# Umbral aplicado (media + desviación): 1.39
#
# --- Grupo: carry out calculations ---
# Total de palabras (antes del filtrado): 57
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.54
# Desviación típica: 1.23
# Umbral aplicado (media + desviación): 2.77
#
# --- Grupo: carrying out forensic and police investigations ---
# Total de palabras (antes del filtrado): 7
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.43
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 1.96
#
# --- Grupo: check quality of raw materials ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.19
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: chemical engineering and processes ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.30
# Desviación típica: 0.67
# Umbral aplicado (media + desviación): 1.97
#
# --- Grupo: chemistry ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.22
# Desviación típica: 0.67
# Umbral aplicado (media + desviación): 1.89
#
# --- Grupo: cloud technologies ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.41
# Desviación típica: 0.96
# Umbral aplicado (media + desviación): 2.37
#
# --- Grupo: collaborate through digital technologies ---
# Total de palabras (antes del filtrado): 31
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.19
# Desviación típica: 0.54
# Umbral aplicado (media + desviación): 1.74
#
# --- Grupo: collect ICT data ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.31
# Desviación típica: 0.79
# Umbral aplicado (media + desviación): 2.11
#
# --- Grupo: collect mapping data ---
# Total de palabras (antes del filtrado): 6
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: collection management ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.50
# Desviación típica: 0.76
# Umbral aplicado (media + desviación): 2.26
#
# --- Grupo: communication, collaboration and creativity ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.24
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.67
#
# --- Grupo: compile content ---
# Total de palabras (antes del filtrado): 24
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.25
# Desviación típica: 0.68
# Umbral aplicado (media + desviación): 1.93
#
# --- Grupo: complying with environmental protection laws and standards ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.80
# Desviación típica: 1.03
# Umbral aplicado (media + desviación): 2.83
#
# --- Grupo: complying with health and safety procedures ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.29
# Desviación típica: 0.59
# Umbral aplicado (media + desviación): 1.88
#
# --- Grupo: complying with operational procedures ---
# Total de palabras (antes del filtrado): 63
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.60
# Desviación típica: 1.31
# Umbral aplicado (media + desviación): 2.92
#
# --- Grupo: composing music ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.47
# Desviación típica: 0.72
# Umbral aplicado (media + desviación): 2.19
#
# --- Grupo: computer programming ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.18
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 1.71
#
# --- Grupo: computer technology ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.15
# Desviación típica: 0.55
# Umbral aplicado (media + desviación): 1.71
#
# --- Grupo: computer use ---
# Total de palabras (antes del filtrado): 337
# Total de palabras (después del filtrado): 21
# Media de frecuencia: 1.97
# Desviación típica: 2.18
# Umbral aplicado (media + desviación): 4.14
#
# --- Grupo: conduct web searches ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.38
# Desviación típica: 0.72
# Umbral aplicado (media + desviación): 2.09
#
# --- Grupo: conducting academic or market research ---
# Total de palabras (antes del filtrado): 93
# Total de palabras (después del filtrado): 9
# Media de frecuencia: 1.52
# Desviación típica: 1.19
# Umbral aplicado (media + desviación): 2.70
#
# --- Grupo: conducting gaming activities ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.36
# Desviación típica: 0.79
# Umbral aplicado (media + desviación): 2.15
#
# --- Grupo: conducting studies, investigations and examinations ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.23
# Desviación típica: 0.43
# Umbral aplicado (media + desviación): 1.66
#
# --- Grupo: content development processes ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.25
# Desviación típica: 0.45
# Umbral aplicado (media + desviación): 1.70
#
# --- Grupo: control production ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.76
# Desviación típica: 1.39
# Umbral aplicado (media + desviación): 3.16
#
# --- Grupo: control systems ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.25
# Desviación típica: 0.46
# Umbral aplicado (media + desviación): 1.71
#
# --- Grupo: coordinate audio system programmes ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.50
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: coordinate marketing plan actions ---
# Total de palabras (antes del filtrado): 21
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: coordinate remote communications ---
# Total de palabras (antes del filtrado): 26
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.58
# Desviación típica: 1.30
# Umbral aplicado (media + desviación): 2.88
#
# --- Grupo: create 3D characters ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.19
# Desviación típica: 0.54
# Umbral aplicado (media + desviación): 1.73
#
# --- Grupo: create digital content ---
# Total de palabras (antes del filtrado): 33
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.52
# Desviación típica: 1.28
# Umbral aplicado (media + desviación): 2.79
#
# --- Grupo: create digital images ---
# Total de palabras (antes del filtrado): 33
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.61
# Desviación típica: 1.12
# Umbral aplicado (media + desviación): 2.72
#
# --- Grupo: create new concepts ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.27
# Desviación típica: 0.59
# Umbral aplicado (media + desviación): 1.86
#
# --- Grupo: create patterns for garments ---
# Total de palabras (antes del filtrado): 19
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.26
# Desviación típica: 0.56
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: create sketches ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.33
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.82
#
# --- Grupo: create software design ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.38
# Desviación típica: 0.51
# Umbral aplicado (media + desviación): 1.89
#
# --- Grupo: create solutions to problems ---
# Total de palabras (antes del filtrado): 39
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.33
# Desviación típica: 0.84
# Umbral aplicado (media + desviación): 2.17
#
# --- Grupo: creating artistic designs or performances ---
# Total de palabras (antes del filtrado): 83
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.47
# Desviación típica: 0.97
# Umbral aplicado (media + desviación): 2.44
#
# --- Grupo: creating visual displays and decorations ---
# Total de palabras (antes del filtrado): 72
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.97
# Desviación típica: 1.66
# Umbral aplicado (media + desviación): 3.63
#
# --- Grupo: creatively use digital technologies ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.07
# Desviación típica: 0.27
# Umbral aplicado (media + desviación): 1.34
#
# --- Grupo: crop and livestock production ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.10
# Desviación típica: 0.31
# Umbral aplicado (media + desviación): 1.41
#
# --- Grupo: cue a performance ---
# Total de palabras (antes del filtrado): 5
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 2.00
# Desviación típica: 0.71
# Umbral aplicado (media + desviación): 2.71
#
# --- Grupo: data mining ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.18
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: database ---
# Total de palabras (antes del filtrado): 6
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.33
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: database and network design and administration ---
# Total de palabras (antes del filtrado): 476
# Total de palabras (después del filtrado): 37
# Media de frecuencia: 2.84
# Desviación típica: 4.25
# Umbral aplicado (media + desviación): 7.09
#
# --- Grupo: define integration strategy ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.23
# Desviación típica: 0.60
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: define technology strategy ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.38
# Desviación típica: 0.72
# Umbral aplicado (media + desviación): 2.09
#
# --- Grupo: demonstrate loyalty ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.32
# Desviación típica: 0.89
# Umbral aplicado (media + desviación): 2.21
#
# --- Grupo: demonstrate willingness to learn ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.41
# Desviación típica: 0.62
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: deploy ICT systems ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.33
# Desviación típica: 0.82
# Umbral aplicado (media + desviación): 2.15
#
# --- Grupo: design application interfaces ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.27
# Desviación típica: 0.47
# Umbral aplicado (media + desviación): 1.74
#
# --- Grupo: design component interfaces ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.27
# Desviación típica: 0.47
# Umbral aplicado (media + desviación): 1.74
#
# --- Grupo: design engineering components ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.18
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: design graphics ---
# Total de palabras (antes del filtrado): 31
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.32
# Desviación típica: 0.83
# Umbral aplicado (media + desviación): 2.15
#
# --- Grupo: design information system ---
# Total de palabras (antes del filtrado): 18
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.33
# Desviación típica: 0.77
# Umbral aplicado (media + desviación): 2.10
#
# --- Grupo: design process ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.47
# Desviación típica: 0.80
# Umbral aplicado (media + desviación): 2.27
#
# --- Grupo: design prototypes ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.33
# Desviación típica: 0.50
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: design wearing apparel ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.33
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.82
#
# --- Grupo: designing electrical or electronic systems or equipment ---
# Total de palabras (antes del filtrado): 87
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 2.78
# Desviación típica: 3.86
# Umbral aplicado (media + desviación): 6.64
#
# --- Grupo: designing ict systems or applications ---
# Total de palabras (antes del filtrado): 309
# Total de palabras (después del filtrado): 24
# Media de frecuencia: 2.33
# Desviación típica: 3.09
# Umbral aplicado (media + desviación): 5.41
#
# --- Grupo: designing industrial materials, systems or products ---
# Total de palabras (antes del filtrado): 99
# Total de palabras (después del filtrado): 14
# Media de frecuencia: 2.01
# Desviación típica: 1.95
# Umbral aplicado (media + desviación): 3.96
#
# --- Grupo: designing structures or facilities ---
# Total de palabras (antes del filtrado): 48
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.50
# Desviación típica: 1.15
# Umbral aplicado (media + desviación): 2.65
#
# --- Grupo: designing systems and products ---
# Total de palabras (antes del filtrado): 57
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.70
# Desviación típica: 1.59
# Umbral aplicado (media + desviación): 3.29
#
# --- Grupo: detect rail track malfunctions ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.33
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: develop a specific interior design ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.46
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.98
#
# --- Grupo: develop automated software tests ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.31
# Desviación típica: 0.85
# Umbral aplicado (media + desviación): 2.16
#
# --- Grupo: develop educational resources ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.19
# Desviación típica: 0.54
# Umbral aplicado (media + desviación): 1.73
#
# --- Grupo: develop strategy to solve problems ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.40
# Desviación típica: 0.70
# Umbral aplicado (media + desviación): 2.10
#
# --- Grupo: developing contingency and emergency response plans ---
# Total de palabras (antes del filtrado): 45
# Total de palabras (después del filtrado): 9
# Media de frecuencia: 1.27
# Desviación típica: 0.58
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: developing educational programmes ---
# Total de palabras (antes del filtrado): 19
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.32
# Desviación típica: 0.48
# Umbral aplicado (media + desviación): 1.79
#
# --- Grupo: developing financial, business or marketing plans ---
# Total de palabras (antes del filtrado): 74
# Total de palabras (después del filtrado): 9
# Media de frecuencia: 1.72
# Desviación típica: 1.57
# Umbral aplicado (media + desviación): 3.28
#
# --- Grupo: developing instructive or promotional materials ---
# Total de palabras (antes del filtrado): 24
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.29
# Desviación típica: 0.62
# Umbral aplicado (media + desviación): 1.92
#
# --- Grupo: developing operational policies and procedures ---
# Total de palabras (antes del filtrado): 95
# Total de palabras (después del filtrado): 16
# Media de frecuencia: 1.57
# Desviación típica: 1.12
# Umbral aplicado (media + desviación): 2.69
#
# --- Grupo: developing solutions ---
# Total de palabras (antes del filtrado): 48
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.67
# Desviación típica: 0.95
# Umbral aplicado (media + desviación): 2.62
#
# --- Grupo: diagnosing health conditions ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.07
# Desviación típica: 0.26
# Umbral aplicado (media + desviación): 1.32
#
# --- Grupo: digital communication and collaboration ---
# Total de palabras (antes del filtrado): 52
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.60
# Desviación típica: 1.19
# Umbral aplicado (media + desviación): 2.79
#
# --- Grupo: digital content creation ---
# Total de palabras (antes del filtrado): 43
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.35
# Desviación típica: 1.11
# Umbral aplicado (media + desviación): 2.46
#
# --- Grupo: digital data processing ---
# Total de palabras (antes del filtrado): 29
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.97
# Desviación típica: 1.97
# Umbral aplicado (media + desviación): 3.94
#
# --- Grupo: directing operational activities ---
# Total de palabras (antes del filtrado): 35
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.26
# Desviación típica: 0.51
# Umbral aplicado (media + desviación): 1.76
#
# --- Grupo: directing, supervising and coordinating projects ---
# Total de palabras (antes del filtrado): 19
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.32
# Desviación típica: 0.67
# Umbral aplicado (media + desviación): 1.99
#
# --- Grupo: documenting and recording information ---
# Total de palabras (antes del filtrado): 30
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.57
# Desviación típica: 0.94
# Umbral aplicado (media + desviación): 2.50
#
# --- Grupo: documenting technical designs, procedures, problems or activities ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.42
# Desviación típica: 0.51
# Umbral aplicado (media + desviación): 1.93
#
# --- Grupo: earth sciences ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.73
# Desviación típica: 1.16
# Umbral aplicado (media + desviación): 2.89
#
# --- Grupo: edit digital moving images ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.17
# Desviación típica: 0.39
# Umbral aplicado (media + desviación): 1.56
#
# --- Grupo: education science ---
# Total de palabras (antes del filtrado): 24
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.29
# Desviación típica: 0.62
# Umbral aplicado (media + desviación): 1.92
#
# --- Grupo: electricity and energy ---
# Total de palabras (antes del filtrado): 43
# Total de palabras (después del filtrado): 9
# Media de frecuencia: 1.30
# Desviación típica: 0.67
# Umbral aplicado (media + desviación): 1.98
#
# --- Grupo: electronics ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.20
# Desviación típica: 0.42
# Umbral aplicado (media + desviación): 1.62
#
# --- Grupo: electronics and automation ---
# Total de palabras (antes del filtrado): 239
# Total de palabras (después del filtrado): 19
# Media de frecuencia: 2.34
# Desviación típica: 3.21
# Umbral aplicado (media + desviación): 5.55
#
# --- Grupo: energy efficiency ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.46
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.98
#
# --- Grupo: engineering and engineering trades not elsewhere classified ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.09
# Desviación típica: 0.30
# Umbral aplicado (media + desviación): 1.39
#
# --- Grupo: engineering and engineering trades not further defined ---
# Total de palabras (antes del filtrado): 25
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.64
# Desviación típica: 1.15
# Umbral aplicado (media + desviación): 2.79
#
# --- Grupo: engineering, manufacturing and construction not elsewhere classified ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: enhance production workflow ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.06
# Desviación típica: 0.25
# Umbral aplicado (media + desviación): 1.31
#
# --- Grupo: entering and transforming information ---
# Total de palabras (antes del filtrado): 103
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.70
# Desviación típica: 1.80
# Umbral aplicado (media + desviación): 3.50
#
# --- Grupo: environmental protection technology ---
# Total de palabras (antes del filtrado): 19
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: establish data processes ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.12
# Desviación típica: 0.34
# Umbral aplicado (media + desviación): 1.47
#
# --- Grupo: estimating resource needs ---
# Total de palabras (antes del filtrado): 23
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.43
# Desviación típica: 0.73
# Umbral aplicado (media + desviación): 2.16
#
# --- Grupo: evaluate data, information and digital content ---
# Total de palabras (antes del filtrado): 63
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.62
# Desviación típica: 1.64
# Umbral aplicado (media + desviación): 3.26
#
# --- Grupo: evaluate environmental impact of personal behaviour ---
# Total de palabras (antes del filtrado): 6
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.50
# Desviación típica: 0.55
# Umbral aplicado (media + desviación): 2.05
#
# --- Grupo: evaluating systems, programmes, equipment and products ---
# Total de palabras (antes del filtrado): 86
# Total de palabras (después del filtrado): 10
# Media de frecuencia: 1.59
# Desviación típica: 1.18
# Umbral aplicado (media + desviación): 2.78
#
# --- Grupo: execute software tests ---
# Total de palabras (antes del filtrado): 45
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.58
# Desviación típica: 1.48
# Umbral aplicado (media + desviación): 3.06
#
# --- Grupo: executing financial transactions ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.56
# Desviación típica: 0.73
# Umbral aplicado (media + desviación): 2.28
#
# --- Grupo: finance, banking and insurance ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.06
# Desviación típica: 0.24
# Umbral aplicado (media + desviación): 1.30
#
# --- Grupo: fisheries ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.50
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: fluid mechanics ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.25
# Desviación típica: 0.71
# Umbral aplicado (media + desviación): 1.96
#
# --- Grupo: gather data ---
# Total de palabras (antes del filtrado): 36
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.47
# Desviación típica: 1.11
# Umbral aplicado (media + desviación): 2.58
#
# --- Grupo: gather experimental data ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.62
# Desviación típica: 0.74
# Umbral aplicado (media + desviación): 2.37
#
# --- Grupo: gathering information from physical or electronic sources ---
# Total de palabras (antes del filtrado): 81
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.75
# Desviación típica: 2.19
# Umbral aplicado (media + desviación): 3.95
#
# --- Grupo: history ---
# Total de palabras (antes del filtrado): 6
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.33
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: history and archaeology ---
# Total de palabras (antes del filtrado): 6
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.33
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: hotel, restaurants and catering ---
# Total de palabras (antes del filtrado): 23
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.09
# Desviación típica: 0.29
# Umbral aplicado (media + desviación): 1.38
#
# --- Grupo: identify ICT security risks ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.25
# Desviación típica: 0.72
# Umbral aplicado (media + desviación): 1.97
#
# --- Grupo: identify ICT user needs ---
# Total de palabras (antes del filtrado): 33
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.30
# Desviación típica: 0.59
# Umbral aplicado (media + desviación): 1.89
#
# --- Grupo: identify digital competence gaps ---
# Total de palabras (antes del filtrado): 24
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.12
# Desviación típica: 0.34
# Umbral aplicado (media + desviación): 1.46
#
# --- Grupo: identify problems ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.62
# Desviación típica: 0.92
# Umbral aplicado (media + desviación): 2.54
#
# --- Grupo: identify technological needs ---
# Total de palabras (antes del filtrado): 29
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.34
# Desviación típica: 0.72
# Umbral aplicado (media + desviación): 2.07
#
# --- Grupo: identifying opportunities ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.44
# Desviación típica: 0.73
# Umbral aplicado (media + desviación): 2.16
#
# --- Grupo: implement ICT risk management ---
# Total de palabras (antes del filtrado): 44
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.57
# Desviación típica: 1.15
# Umbral aplicado (media + desviación): 2.72
#
# --- Grupo: implementing new procedures or processes ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.40
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.92
#
# --- Grupo: information and communication technologies not elsewhere classified ---
# Total de palabras (antes del filtrado): 178
# Total de palabras (después del filtrado): 17
# Media de frecuencia: 1.82
# Desviación típica: 1.56
# Umbral aplicado (media + desviación): 3.38
#
# --- Grupo: information skills ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.20
# Desviación típica: 0.41
# Umbral aplicado (media + desviación): 1.61
#
# --- Grupo: inspect data ---
# Total de palabras (antes del filtrado): 38
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.42
# Desviación típica: 1.27
# Umbral aplicado (media + desviación): 2.69
#
# --- Grupo: install electrical and electronic equipment ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.40
# Desviación típica: 0.70
# Umbral aplicado (media + desviación): 2.10
#
# --- Grupo: install electronic communication equipment ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.21
# Desviación típica: 0.43
# Umbral aplicado (media + desviación): 1.64
#
# --- Grupo: installing and repairing electrical, electronic and precision equipment ---
# Total de palabras (antes del filtrado): 135
# Total de palabras (después del filtrado): 11
# Media de frecuencia: 2.15
# Desviación típica: 2.69
# Umbral aplicado (media + desviación): 4.83
#
# --- Grupo: installing wooden and metal components ---
# Total de palabras (antes del filtrado): 111
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 2.30
# Desviación típica: 3.50
# Umbral aplicado (media + desviación): 5.80
#
# --- Grupo: instruct others ---
# Total de palabras (antes del filtrado): 78
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.65
# Desviación típica: 1.51
# Umbral aplicado (media + desviación): 3.16
#
# --- Grupo: integrate ICT data ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.23
# Desviación típica: 0.60
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: integrate and re-elaborate digital content ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.08
# Desviación típica: 0.29
# Umbral aplicado (media + desviación): 1.37
#
# --- Grupo: inter-disciplinary programmes and qualifications involving education ---
# Total de palabras (antes del filtrado): 33
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.27
# Desviación típica: 0.57
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: inter-disciplinary programmes and qualifications involving information and communication technologies (icts) ---
# Total de palabras (antes del filtrado): 98
# Total de palabras (después del filtrado): 10
# Media de frecuencia: 1.59
# Desviación típica: 1.22
# Umbral aplicado (media + desviación): 2.81
#
# --- Grupo: inter-disciplinary programmes and qualifications involving natural sciences, mathematics and statistics ---
# Total de palabras (antes del filtrado): 38
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.32
# Desviación típica: 0.87
# Umbral aplicado (media + desviación): 2.19
#
# --- Grupo: inter-disciplinary programmes and qualifications involving social sciences, journalism and information ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: interact through digital technologies ---
# Total de palabras (antes del filtrado): 25
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.32
# Desviación típica: 0.80
# Umbral aplicado (media + desviación): 2.12
#
# --- Grupo: interpret current data ---
# Total de palabras (antes del filtrado): 26
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.38
# Desviación típica: 0.94
# Umbral aplicado (media + desviación): 2.33
#
# --- Grupo: interpret graphical communication interfaces ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.33
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: interpret visual literacy ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.07
# Desviación típica: 0.27
# Umbral aplicado (media + desviación): 1.34
#
# --- Grupo: interpreting technical documentation and diagrams ---
# Total de palabras (antes del filtrado): 21
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.19
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: journalism ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: journalism and reporting ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: keep up to date on product knowledge ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.22
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.66
#
# --- Grupo: keep up with trends ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.22
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.66
#
# --- Grupo: keep up-to-date with regulations ---
# Total de palabras (antes del filtrado): 19
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.42
# Desviación típica: 0.61
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: language acquisition ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.09
# Desviación típica: 0.30
# Umbral aplicado (media + desviación): 1.39
#
# --- Grupo: law ---
# Total de palabras (antes del filtrado): 35
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.20
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 1.73
#
# --- Grupo: lead a team ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.53
# Desviación típica: 0.74
# Umbral aplicado (media + desviación): 2.28
#
# --- Grupo: lead others ---
# Total de palabras (antes del filtrado): 56
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.50
# Desviación típica: 0.97
# Umbral aplicado (media + desviación): 2.47
#
# --- Grupo: leading and motivating ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.14
# Desviación típica: 0.35
# Umbral aplicado (media + desviación): 1.49
#
# --- Grupo: learning technologies ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: liaising and networking ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.30
# Desviación típica: 0.67
# Umbral aplicado (media + desviación): 1.97
#
# --- Grupo: library, information and archival studies ---
# Total de palabras (antes del filtrado): 59
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.44
# Desviación típica: 0.79
# Umbral aplicado (media + desviación): 2.23
#
# --- Grupo: linguistics ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.20
# Desviación típica: 0.42
# Umbral aplicado (media + desviación): 1.62
#
# --- Grupo: literature and linguistics ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.25
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.69
#
# --- Grupo: maintain ICT server ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.36
# Desviación típica: 1.08
# Umbral aplicado (media + desviación): 2.44
#
# --- Grupo: maintain ICT system ---
# Total de palabras (antes del filtrado): 61
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.52
# Desviación típica: 1.13
# Umbral aplicado (media + desviación): 2.66
#
# --- Grupo: maintain computer hardware ---
# Total de palabras (antes del filtrado): 21
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.19
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: maintain electrical equipment ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.27
# Desviación típica: 0.59
# Umbral aplicado (media + desviación): 1.86
#
# --- Grupo: maintain equipment ---
# Total de palabras (antes del filtrado): 39
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 2.33
# Desviación típica: 2.20
# Umbral aplicado (media + desviación): 4.54
#
# --- Grupo: maintain freelance database ---
# Total de palabras (antes del filtrado): 24
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.33
# Desviación típica: 0.70
# Umbral aplicado (media + desviación): 2.04
#
# --- Grupo: maintain irrigation systems ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.40
# Desviación típica: 0.75
# Umbral aplicado (media + desviación): 2.15
#
# --- Grupo: maintain lighting equipment ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.50
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: maintain microelectronics ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.15
# Desviación típica: 0.38
# Umbral aplicado (media + desviación): 1.53
#
# --- Grupo: maintain operational communications ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.70
# Desviación típica: 0.95
# Umbral aplicado (media + desviación): 2.65
#
# --- Grupo: maintain up-to-date aeronautical information management services ---
# Total de palabras (antes del filtrado): 13
# Total de palabras (después del filtrado): 2
# ...
# Umbral aplicado (media + desviación): 2.18
#
# --- Grupo: setting up computer systems ---
# Total de palabras (antes del filtrado): 222
# Total de palabras (después del filtrado): 19
# Media de frecuencia: 2.36
# Desviación típica: 3.21
# Umbral aplicado (media + desviación): 5.58
#
# --- Grupo: share through digital technologies ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.25
# Desviación típica: 0.68
# Umbral aplicado (media + desviación): 1.93
#
# --- Grupo: simplify communication in maritime management ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.56
# Desviación típica: 0.73
# Umbral aplicado (media + desviación): 2.28
#
# --- Grupo: social media management ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.56
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 2.08
#
# --- Grupo: software and applications development and analysis ---
# Total de palabras (antes del filtrado): 355
# Total de palabras (después del filtrado): 21
# Media de frecuencia: 2.81
# Desviación típica: 5.04
# Umbral aplicado (media + desviación): 7.84
#
# --- Grupo: software architecture models ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.20
# Desviación típica: 0.42
# Umbral aplicado (media + desviación): 1.62
#
# --- Grupo: software design methodologies ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.21
# Desviación típica: 0.43
# Umbral aplicado (media + desviación): 1.64
#
# --- Grupo: software interaction design ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.21
# Desviación típica: 0.43
# Umbral aplicado (media + desviación): 1.64
#
# --- Grupo: solve location and navigation problems by using GPS tools ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.50
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: solve technical problems ---
# Total de palabras (antes del filtrado): 58
# Total de palabras (después del filtrado): 5
# Media de frecuencia: 1.60
# Desviación típica: 1.43
# Umbral aplicado (media + desviación): 3.03
#
# --- Grupo: sorting materials or products ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.42
# Desviación típica: 0.67
# Umbral aplicado (media + desviación): 2.09
#
# --- Grupo: statistics ---
# Total de palabras (antes del filtrado): 35
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.43
# Desviación típica: 0.95
# Umbral aplicado (media + desviación): 2.38
#
# --- Grupo: store digital data and systems ---
# Total de palabras (antes del filtrado): 83
# Total de palabras (después del filtrado): 10
# Media de frecuencia: 1.57
# Desviación típica: 1.31
# Umbral aplicado (media + desviación): 2.87
#
# --- Grupo: storing goods and materials ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.38
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.89
#
# --- Grupo: supervising a team or group ---
# Total de palabras (antes del filtrado): 41
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.46
# Desviación típica: 0.81
# Umbral aplicado (media + desviación): 2.27
#
# --- Grupo: support ICT system users ---
# Total de palabras (antes del filtrado): 32
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.31
# Desviación típica: 0.82
# Umbral aplicado (media + desviación): 2.13
#
# --- Grupo: synchronise sound with images ---
# Total de palabras (antes del filtrado): 7
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.43
# Desviación típica: 0.53
# Umbral aplicado (media + desviación): 1.96
#
# --- Grupo: teacher training with subject specialisation ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.18
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: teacher training without subject specialisation ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.27
# Desviación típica: 0.70
# Umbral aplicado (media + desviación): 1.97
#
# --- Grupo: teaching academic or vocational subjects ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.19
# Desviación típica: 0.40
# Umbral aplicado (media + desviación): 1.59
#
# --- Grupo: teaching and training ---
# Total de palabras (antes del filtrado): 37
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.59
# Desviación típica: 1.28
# Umbral aplicado (media + desviación): 2.87
#
# --- Grupo: technical or academic writing ---
# Total de palabras (antes del filtrado): 67
# Total de palabras (después del filtrado): 17
# Media de frecuencia: 1.30
# Desviación típica: 0.55
# Umbral aplicado (media + desviación): 1.85
#
# --- Grupo: tend lathe ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.30
# Desviación típica: 0.47
# Umbral aplicado (media + desviación): 1.77
#
# --- Grupo: tend punch press ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.33
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: test hardware ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.27
# Desviación típica: 0.46
# Umbral aplicado (media + desviación): 1.72
#
# --- Grupo: testing and analysing substances ---
# Total de palabras (antes del filtrado): 35
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.37
# Desviación típica: 0.81
# Umbral aplicado (media + desviación): 2.18
#
# --- Grupo: testing electrical and mechanical systems or equipment ---
# Total de palabras (antes del filtrado): 45
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.36
# Desviación típica: 0.68
# Umbral aplicado (media + desviación): 2.03
#
# --- Grupo: textiles (clothes, footwear and leather) ---
# Total de palabras (antes del filtrado): 28
# Total de palabras (después del filtrado): 7
# Media de frecuencia: 1.32
# Desviación típica: 0.61
# Umbral aplicado (media + desviación): 1.93
#
# --- Grupo: think analytically ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.20
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.72
#
# --- Grupo: think creatively ---
# Total de palabras (antes del filtrado): 15
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.27
# Desviación típica: 0.59
# Umbral aplicado (media + desviación): 1.86
#
# --- Grupo: think critically ---
# Total de palabras (antes del filtrado): 105
# Total de palabras (después del filtrado): 9
# Media de frecuencia: 1.83
# Desviación típica: 1.95
# Umbral aplicado (media + desviación): 3.78
#
# --- Grupo: think innovatively ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.24
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.67
#
# --- Grupo: toys and games trends ---
# Total de palabras (antes del filtrado): 4
# Total de palabras (después del filtrado): 0
# Media de frecuencia: 1.00
# Desviación típica: 0.00
# Umbral aplicado (media + desviación): 1.00
#
# --- Grupo: train employees ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.27
# Desviación típica: 0.90
# Umbral aplicado (media + desviación): 2.18
#
# --- Grupo: training on operational procedures ---
# Total de palabras (antes del filtrado): 81
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.46
# Desviación típica: 0.87
# Umbral aplicado (media + desviación): 2.32
#
# --- Grupo: translating and interpreting ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.38
# Desviación típica: 0.52
# Umbral aplicado (media + desviación): 1.89
#
# --- Grupo: transport services ---
# Total de palabras (antes del filtrado): 68
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.60
# Desviación típica: 1.25
# Umbral aplicado (media + desviación): 2.85
#
# --- Grupo: troubleshoot ---
# Total de palabras (antes del filtrado): 52
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.33
# Desviación típica: 0.68
# Umbral aplicado (media + desviación): 2.00
#
# --- Grupo: use CAD software ---
# Total de palabras (antes del filtrado): 93
# Total de palabras (después del filtrado): 16
# Media de frecuencia: 2.39
# Desviación típica: 2.38
# Umbral aplicado (media + desviación): 4.77
#
# --- Grupo: use ICT systems ---
# Total de palabras (antes del filtrado): 42
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.38
# Desviación típica: 1.08
# Umbral aplicado (media + desviación): 2.46
#
# --- Grupo: use agricultural information systems and databases ---
# Total de palabras (antes del filtrado): 8
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.50
# Desviación típica: 0.76
# Umbral aplicado (media + desviación): 2.26
#
# --- Grupo: use audio reproduction software ---
# Total de palabras (antes del filtrado): 5
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.40
# Desviación típica: 0.55
# Umbral aplicado (media + desviación): 1.95
#
# --- Grupo: use communication and collaboration software ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.40
# Desviación típica: 0.68
# Umbral aplicado (media + desviación): 2.08
#
# --- Grupo: use communication equipment ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.25
# Desviación típica: 0.45
# Umbral aplicado (media + desviación): 1.70
#
# --- Grupo: use computer-aided translation ---
# Total de palabras (antes del filtrado): 7
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.57
# Desviación típica: 0.79
# Umbral aplicado (media + desviación): 2.36
#
# --- Grupo: use data processing techniques ---
# Total de palabras (antes del filtrado): 32
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.31
# Desviación típica: 1.12
# Umbral aplicado (media + desviación): 2.43
#
# --- Grupo: use databases ---
# Total de palabras (antes del filtrado): 142
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.82
# Desviación típica: 2.57
# Umbral aplicado (media + desviación): 4.38
#
# --- Grupo: use digital illustration techniques ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.33
# Desviación típica: 0.50
# Umbral aplicado (media + desviación): 1.83
#
# --- Grupo: use e-services ---
# Total de palabras (antes del filtrado): 27
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.59
# Desviación típica: 0.97
# Umbral aplicado (media + desviación): 2.56
#
# --- Grupo: use learning strategies ---
# Total de palabras (antes del filtrado): 10
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.20
# Desviación típica: 0.42
# Umbral aplicado (media + desviación): 1.62
#
# --- Grupo: use measurement instruments ---
# Total de palabras (antes del filtrado): 26
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.54
# Desviación típica: 0.86
# Umbral aplicado (media + desviación): 2.40
#
# --- Grupo: use online tools to collaborate ---
# Total de palabras (antes del filtrado): 31
# Total de palabras (después del filtrado): 4
# Media de frecuencia: 1.19
# Desviación típica: 0.54
# Umbral aplicado (media + desviación): 1.74
#
# --- Grupo: use production planning software ---
# Total de palabras (antes del filtrado): 14
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.64
# Desviación típica: 1.01
# Umbral aplicado (media + desviación): 2.65
#
# --- Grupo: use shorthand ---
# Total de palabras (antes del filtrado): 12
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.25
# Desviación típica: 0.62
# Umbral aplicado (media + desviación): 1.87
#
# --- Grupo: use specific data analysis software ---
# Total de palabras (antes del filtrado): 9
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.22
# Desviación típica: 0.44
# Umbral aplicado (media + desviación): 1.66
#
# --- Grupo: use technical drawing software ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.68
# Desviación típica: 1.09
# Umbral aplicado (media + desviación): 2.77
#
# --- Grupo: using computer aided design and drawing tools ---
# Total de palabras (antes del filtrado): 205
# Total de palabras (después del filtrado): 15
# Media de frecuencia: 2.71
# Desviación típica: 3.79
# Umbral aplicado (media + desviación): 6.50
#
# --- Grupo: using digital tools for collaboration and productivity ---
# Total de palabras (antes del filtrado): 240
# Total de palabras (después del filtrado): 11
# Media de frecuencia: 2.18
# Desviación típica: 3.30
# Umbral aplicado (media + desviación): 5.49
#
# --- Grupo: using digital tools for collaboration, content creation and problem solving ---
# Total de palabras (antes del filtrado): 11
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.09
# Desviación típica: 0.30
# Umbral aplicado (media + desviación): 1.39
#
# --- Grupo: using digital tools for processing sound and images ---
# Total de palabras (antes del filtrado): 128
# Total de palabras (después del filtrado): 10
# Media de frecuencia: 2.02
# Desviación típica: 2.28
# Umbral aplicado (media + desviación): 4.30
#
# --- Grupo: using digital tools to control machinery ---
# Total de palabras (antes del filtrado): 170
# Total de palabras (después del filtrado): 14
# Media de frecuencia: 2.87
# Desviación típica: 4.86
# Umbral aplicado (media + desviación): 7.73
#
# --- Grupo: using precision instrumentation and equipment ---
# Total de palabras (antes del filtrado): 40
# Total de palabras (después del filtrado): 10
# Media de frecuencia: 1.32
# Desviación típica: 0.66
# Umbral aplicado (media + desviación): 1.98
#
# --- Grupo: using precision measuring equipment ---
# Total de palabras (antes del filtrado): 56
# Total de palabras (después del filtrado): 8
# Media de frecuencia: 1.57
# Desviación típica: 1.02
# Umbral aplicado (media + desviación): 2.60
#
# --- Grupo: using word processing, publishing and presentation software ---
# Total de palabras (antes del filtrado): 47
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.72
# Desviación típica: 1.25
# Umbral aplicado (media + desviación): 2.97
#
# --- Grupo: verifying identities and documentation ---
# Total de palabras (antes del filtrado): 17
# Total de palabras (después del filtrado): 1
# Media de frecuencia: 1.12
# Desviación típica: 0.49
# Umbral aplicado (media + desviación): 1.60
#
# --- Grupo: wholesale and retail sales ---
# Total de palabras (antes del filtrado): 22
# Total de palabras (después del filtrado): 3
# Media de frecuencia: 1.18
# Desviación típica: 0.50
# Umbral aplicado (media + desviación): 1.68
#
# --- Grupo: work skills ---
# Total de palabras (antes del filtrado): 16
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.38
# Desviación típica: 1.09
# Umbral aplicado (media + desviación): 2.46
#
# --- Grupo: working with computers ---
# Total de palabras (antes del filtrado): 117
# Total de palabras (después del filtrado): 15
# Media de frecuencia: 1.60
# Desviación típica: 1.34
# Umbral aplicado (media + desviación): 2.94
#
# --- Grupo: working with digital devices and applications ---
# Total de palabras (antes del filtrado): 63
# Total de palabras (después del filtrado): 6
# Media de frecuencia: 1.46
# Desviación típica: 0.82
# Umbral aplicado (media + desviación): 2.28
#
# --- Grupo: working with machinery and specialised equipment ---
# Total de palabras (antes del filtrado): 20
# Total de palabras (después del filtrado): 2
# Media de frecuencia: 1.10
# Desviación típica: 0.31
# Umbral aplicado (media + desviación): 1.41

# %% [markdown]
# ## Construcción de matrices de frecuencias por grupo
#
# En este bloque se preparan las matrices de frecuencias necesarias para los análisis posteriores. Para ello:
#
# 1. **Se crea una columna combinada `Comp`** que concatena `ID_area` e `ID_competencia` para los casos en los que las agrupaciones sean las competencias.
# 2. **Se generan matrices de frecuencias** mediante `pivot_table()`, en las que:
#    - Las filas corresponden a palabras.
#    - Las columnas representan los distintos grupos.
#    - Los valores son las frecuencias de aparición de cada palabra en cada grupo.
# 3. **Se exportan las matrices a archivos `.csv`**.
#
# Este paso transforma los datos textuales en estructuras matriciales.
#
# ### Ejemplo simplificado
#
# **Antes del pivoteo:**
#
# | Palabra   | broaderConceptPT | Frecuencia |
# |-----------|------------------|------------|
# | access    | use software     | 3          |
# | digital   | hardware         | 2          |
# | access    | ICT software     | 5          |
#
# **Después del pivoteo:**
#
# | Palabra   | use software | hardware |
# |-----------|--------------|----------|
# | access    | 3            | 5        |
# | digital   | 2            | 0        |

# %%
# Pivotar la tabla para obtener una matriz
# filas = palabras, columnas = grupos, valores = frecuencias
matriz_frecuencias_esco = esco_filtrado.pivot_table(index="Palabra", columns="broaderConceptPT", values="Frecuencia", fill_value=0)
matriz_frecuencias_esco.columns.name = "Palabra"
matriz_frecuencias_esco.index.name = None
matriz_frecuencias_esco.to_csv("../results/esco/frecuencias_esco.csv")
